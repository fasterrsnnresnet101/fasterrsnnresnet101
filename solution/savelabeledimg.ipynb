# %%
# %matplotlib inline
import tarfile
import tensorflow as tf
import zipfile
import sys
import os
import numpy as np

from PIL import Image
from pascal_voc_writer import Writer

from distutils.version import StrictVersion
from collections import defaultdict
from io import StringIO
from matplotlib import pyplot as plt

from object_detection.utils import ops as utils_ops
from object_detection.utils import label_map_util
from object_detection.utils import visualization_utils as vis_util

# to access the object-detection library
sys.path.insert(0, '/data/team01/solution/models/research')
sys.path.append("/data/team01//solution/models/research/slim")

os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID"
os.environ["CUDA_VISIBLE_DEVICES"]="3" # specify which GPU(s) to be used

# path to images
direct = "/data/team01/images/train"
# path to save results
savepath = "/data/team01/solution/reusltsImg/"

# path to frosen graph (model)
PATH_TO_FROZEN_GRAPH = '/data/team01/solution/exported_graphsALL/frozen_inference_graph.pb'

# List of the strings that is used to add correct label for each box.
PATH_TO_LABELS = os.path.join('/data/team01/solution/data', 'object-detection.pbtxt')
category_index = label_map_util.create_category_index_from_labelmap(PATH_TO_LABELS, use_display_name=True)

# Load a (frozen) Tensorflow model into memory
detection_graph = tf.Graph()
with detection_graph.as_default():
  od_graph_def = tf.GraphDef()
  with tf.gfile.GFile(PATH_TO_FROZEN_GRAPH, 'rb') as fid:
    serialized_graph = fid.read()
    od_graph_def.ParseFromString(serialized_graph)
    tf.import_graph_def(od_graph_def, name='')
    
def load_image_into_numpy_array(image):
  (im_width, im_height) = image.size
  return np.array(image.getdata()).reshape(
      (im_height, im_width, 3)).astype(np.uint8)

# Detection of all images in the "direct" directory and then save them to 
def run_inference_for_single_image(graph):
  with graph.as_default():
    IMAGE_SIZE = (12, 8)
    with tf.Session() as sess:
      count = 0

      for root, dirs, files in os.walk(direct):
        for file in files:
          if file.endswith(".jpg"):
            
            count += 1
      rescount = 1
      for root, dirs, files in os.walk(direct):
        for file in files:
          if file.endswith(".jpg"):
            image_path = os.path.join(root, file)
            print("[" + str(rescount) + " : " + str(count) + "]", os.path.join(root, file))
            rescount += 1
            image = Image.open(image_path)
            fileName = os.path.basename(image_path)
            image_np = load_image_into_numpy_array(image)            
            image_np_expanded = np.expand_dims(image_np, axis=0)
            image = image_np
            # the array based representation of the image will be used later in order to prepare the
            # result image with boxes and labels on it.
            
            # Get handles to input and output tensors
            ops = tf.get_default_graph().get_operations()
            all_tensor_names = {output.name for op in ops for output in op.outputs}
            tensor_dict = {}
            for key in [
              'num_detections', 'detection_boxes', 'detection_scores',
              'detection_classes', 'detection_masks'
            ]:
              tensor_name = key + ':0'
              if tensor_name in all_tensor_names:
                tensor_dict[key] = tf.get_default_graph().get_tensor_by_name(
                    tensor_name)
            if 'detection_masks' in tensor_dict:
              # The following processing is only for single image
              detection_boxes = tf.squeeze(tensor_dict['detection_boxes'], [0])
              detection_masks = tf.squeeze(tensor_dict['detection_masks'], [0])
              # Reframe is required to translate mask from box coordinates to image coordinates and fit the image size.
              real_num_detection = tf.cast(tensor_dict['num_detections'][0], tf.int32)
              detection_boxes = tf.slice(detection_boxes, [0, 0], [real_num_detection, -1])
              detection_masks = tf.slice(detection_masks, [0, 0, 0], [real_num_detection, -1, -1])
              detection_masks_reframed = utils_ops.reframe_box_masks_to_image_masks(
                  detection_masks, detection_boxes, image.shape[0], image.shape[1])
              detection_masks_reframed = tf.cast(
                  tf.greater(detection_masks_reframed, 0.5), tf.uint8)
              # Follow the convention by adding back the batch dimension
              tensor_dict['detection_masks'] = tf.expand_dims(
                  detection_masks_reframed, 0)
            image_tensor = tf.get_default_graph().get_tensor_by_name('image_tensor:0')

            # Run inference
            output_dict = sess.run(tensor_dict,
                                   feed_dict={image_tensor: np.expand_dims(image, 0)})
            # all outputs are float32 numpy arrays, so convert types as appropriate
            output_dict['num_detections'] = int(output_dict['num_detections'][0])
            output_dict['detection_classes'] = output_dict['detection_classes'][0].astype(np.uint8)
            output_dict['detection_boxes'] = output_dict['detection_boxes'][0]
            output_dict['detection_scores'] = output_dict['detection_scores'][0]
            if 'detection_masks' in output_dict:
              output_dict['detection_masks'] = output_dict['detection_masks'][0]
            vis_util.visualize_boxes_and_labels_on_image_array(
              image,
              output_dict['detection_boxes'],
              output_dict['detection_classes'],
              output_dict['detection_scores'],
              category_index,
              instance_masks=output_dict.get('detection_masks'),
              use_normalized_coordinates=True,
              line_thickness=2)
            
            plt.imsave(savepath + fileName, image)
run_inference_for_single_image(detection_graph)
# Out:
# [1 : 218] /data/team01/solution/crvidio/DJI Spark- Crossroads in Prague 0721.jpg
# [2 : 218] /data/team01/solution/crvidio/DJI Spark- Crossroads in Prague 0580.jpg
# [3 : 218] /data/team01/solution/crvidio/DJI Spark- Crossroads in Prague 0698.jpg
# [4 : 218] /data/team01/solution/crvidio/DJI Spark- Crossroads in Prague 0670.jpg
# [5 : 218] /data/team01/solution/crvidio/DJI Spark- Crossroads in Prague 0574.jpg
# [6 : 218] /data/team01/solution/crvidio/DJI Spark- Crossroads in Prague 0526.jpg
# [7 : 218] /data/team01/solution/crvidio/DJI Spark- Crossroads in Prague 0697.jpg
# [8 : 218] /data/team01/solution/crvidio/DJI Spark- Crossroads in Prague 0633.jpg
# [9 : 218] /data/team01/solution/crvidio/DJI Spark- Crossroads in Prague 0596.jpg
# [10 : 218] /data/team01/solution/crvidio/DJI Spark- Crossroads in Prague 0619.jpg
# [11 : 218] /data/team01/solution/crvidio/DJI Spark- Crossroads in Prague 0690.jpg
# [12 : 218] /data/team01/solution/crvidio/DJI Spark- Crossroads in Prague 0630.jpg
# [13 : 218] /data/team01/solution/crvidio/DJI Spark- Crossroads in Prague 0715.jpg
# [14 : 218] /data/team01/solution/crvidio/DJI Spark- Crossroads in Prague 0637.jpg
# [15 : 218] /data/team01/solution/crvidio/DJI Spark- Crossroads in Prague 0537.jpg
# [16 : 218] /data/team01/solution/crvidio/DJI Spark- Crossroads in Prague 0728.jpg
# [17 : 218] /data/team01/solution/crvidio/DJI Spark- Crossroads in Prague 0590.jpg
# [18 : 218] /data/team01/solution/crvidio/DJI Spark- Crossroads in Prague 0643.jpg
# [19 : 218] /data/team01/solution/crvidio/DJI Spark- Crossroads in Prague 0625.jpg
# [20 : 218] /data/team01/solution/crvidio/DJI Spark- Crossroads in Prague 0618.jpg
# [21 : 218] /data/team01/solution/crvidio/DJI Spark- Crossroads in Prague 0675.jpg
# [22 : 218] /data/team01/solution/crvidio/DJI Spark- Crossroads in Prague 0733.jpg
# [23 : 218] /data/team01/solution/crvidio/DJI Spark- Crossroads in Prague 0532.jpg
# [24 : 218] /data/team01/solution/crvidio/DJI Spark- Crossroads in Prague 0552.jpg
# [25 : 218] /data/team01/solution/crvidio/DJI Spark- Crossroads in Prague 0535.jpg
# [26 : 218] /data/team01/solution/crvidio/DJI Spark- Crossroads in Prague 0547.jpg
# [27 : 218] /data/team01/solution/crvidio/DJI Spark- Crossroads in Prague 0724.jpg
# [28 : 218] /data/team01/solution/crvidio/DJI Spark- Crossroads in Prague 0719.jpg
# [29 : 218] /data/team01/solution/crvidio/DJI Spark- Crossroads in Prague 0558.jpg
# [30 : 218] /data/team01/solution/crvidio/DJI Spark- Crossroads in Prague 0521.jpg
# [31 : 218] /data/team01/solution/crvidio/DJI Spark- Crossroads in Prague 0542.jpg
# [32 : 218] /data/team01/solution/crvidio/DJI Spark- Crossroads in Prague 0549.jpg
# [33 : 218] /data/team01/solution/crvidio/DJI Spark- Crossroads in Prague 0617.jpg
# [34 : 218] /data/team01/solution/crvidio/DJI Spark- Crossroads in Prague 0668.jpg
# [35 : 218] /data/team01/solution/crvidio/DJI Spark- Crossroads in Prague 0584.jpg
# [36 : 218] /data/team01/solution/crvidio/DJI Spark- Crossroads in Prague 0582.jpg
# [37 : 218] /data/team01/solution/crvidio/DJI Spark- Crossroads in Prague 0636.jpg
# [38 : 218] /data/team01/solution/crvidio/DJI Spark- Crossroads in Prague 0604.jpg
# [39 : 218] /data/team01/solution/crvidio/DJI Spark- Crossroads in Prague 0567.jpg
# [40 : 218] /data/team01/solution/crvidio/DJI Spark- Crossroads in Prague 0626.jpg
# [41 : 218] /data/team01/solution/crvidio/DJI Spark- Crossroads in Prague 0522.jpg
# [42 : 218] /data/team01/solution/crvidio/DJI Spark- Crossroads in Prague 0613.jpg
# [43 : 218] /data/team01/solution/crvidio/DJI Spark- Crossroads in Prague 0645.jpg
# [44 : 218] /data/team01/solution/crvidio/DJI Spark- Crossroads in Prague 0696.jpg
# [45 : 218] /data/team01/solution/crvidio/DJI Spark- Crossroads in Prague 0560.jpg
# [46 : 218] /data/team01/solution/crvidio/DJI Spark- Crossroads in Prague 0536.jpg
# [47 : 218] /data/team01/solution/crvidio/DJI Spark- Crossroads in Prague 0543.jpg
# [48 : 218] /data/team01/solution/crvidio/DJI Spark- Crossroads in Prague 0732.jpg
# [49 : 218] /data/team01/solution/crvidio/DJI Spark- Crossroads in Prague 0608.jpg
# [50 : 218] /data/team01/solution/crvidio/DJI Spark- Crossroads in Prague 0656.jpg
# [51 : 218] /data/team01/solution/crvidio/DJI Spark- Crossroads in Prague 0685.jpg
# [52 : 218] /data/team01/solution/crvidio/DJI Spark- Crossroads in Prague 0553.jpg
# [53 : 218] /data/team01/solution/crvidio/DJI Spark- Crossroads in Prague 0541.jpg
# [54 : 218] /data/team01/solution/crvidio/DJI Spark- Crossroads in Prague 0677.jpg
# [55 : 218] /data/team01/solution/crvidio/DJI Spark- Crossroads in Prague 0531.jpg
# [56 : 218] /data/team01/solution/crvidio/DJI Spark- Crossroads in Prague 0585.jpg
# [57 : 218] /data/team01/solution/crvidio/DJI Spark- Crossroads in Prague 0632.jpg
# [58 : 218] /data/team01/solution/crvidio/DJI Spark- Crossroads in Prague 0627.jpg
# [59 : 218] /data/team01/solution/crvidio/DJI Spark- Crossroads in Prague 0710.jpg
# [60 : 218] /data/team01/solution/crvidio/DJI Spark- Crossroads in Prague 0586.jpg
# [61 : 218] /data/team01/solution/crvidio/DJI Spark- Crossroads in Prague 0667.jpg
# [62 : 218] /data/team01/solution/crvidio/DJI Spark- Crossroads in Prague 0689.jpg
# [63 : 218] /data/team01/solution/crvidio/DJI Spark- Crossroads in Prague 